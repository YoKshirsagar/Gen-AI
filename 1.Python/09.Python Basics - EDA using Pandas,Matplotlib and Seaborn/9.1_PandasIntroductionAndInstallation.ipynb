# %%
import pandas as pd

# %%
df = pd.read_csv("9.1_PandasIntroductionAndInstallation.csv")
df.head(7)           # Print First 7 Rows
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
# 5                     The Shawshank Redemption  Hollywood          1994
# 6                                 Interstellar  Hollywood          2014
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# ...

# %%
df.tail(4)           # Print Last 4 Rows
# Out:
#                         title   industry  release_year  imdb_rating  \
# 33           K.G.F: Chapter 2  Bollywood          2022          8.4
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 33        Hombale Films     1.0     12.5  Billions      INR  Kannada
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
df.sample(4)           # Print Random 4 Rows
# Out:
#                   title   industry  release_year  imdb_rating  \
# 6          Interstellar  Hollywood          2014          8.6
# 28                Sanju  Bollywood          2018          NaN
# 26  Munna Bhai M.B.B.S.  Bollywood          2003          8.1
# 24     Bajirao Mastani   Bollywood          2015          7.2
#
#                       studio  budget  revenue      unit currency language
# 6      Warner Bros. Pictures   165.0    701.8  Millions      USD  English
# 28        Vinod Chopra Films     1.0      5.9  Billions      INR    Hindi
# 26  Vinod Chopra Productions   100.0    410.0  Millions      INR    Hindi
# 24                       NaN     1.4      3.5  Billions      INR    Hindi

# %%
df[2:6]           # Slicing 2-5th Row
# Out:
#                       title   industry  release_year  imdb_rating  \
# 2     Thor: The Dark World   Hollywood          2013          6.8
# 3           Thor: Ragnarok   Hollywood          2017          7.9
# 4   Thor: Love and Thunder   Hollywood          2022          6.8
# 5  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 2             Marvel Studios   165.0    644.8  Millions      USD  English
# 3             Marvel Studios   180.0    854.0  Millions      USD  English
# 4             Marvel Studios   250.0    670.0  Millions      USD  English
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
df.shape
# Out:
# (37, 10)

# %%
df['imdb_rating']
# Out:
# 0     8.3
# 1     7.0
# 2     6.8
# 3     7.9
# 4     6.8
# 5     9.3
# 6     8.6
# 7     8.0
# 8     8.5
# 9     7.9
# 10    8.6
# 11    7.8
# 12    9.2
# 13    9.0
# 14    9.0
# 15    8.2
# 16    8.5
# 17    8.4
# 18    8.4
# 19    6.9
# 20    7.8
# 21    8.0
# 22    8.4
# 23    7.4
# 24    7.2
# 25    8.3
# 26    8.1
# 27    8.1
# 28    NaN
# 29    8.3
# 30    8.1
# 31    1.9
# 32    8.4
# 33    8.4
# 34    7.6
# 35    8.0
# 36    8.0
# Name: imdb_rating, dtype: float64

# %%
df.imdb_rating
# Out:
# 0     8.3
# 1     7.0
# 2     6.8
# 3     7.9
# 4     6.8
# 5     9.3
# 6     8.6
# 7     8.0
# 8     8.5
# 9     7.9
# 10    8.6
# 11    7.8
# 12    9.2
# 13    9.0
# 14    9.0
# 15    8.2
# 16    8.5
# 17    8.4
# 18    8.4
# 19    6.9
# 20    7.8
# 21    8.0
# 22    8.4
# 23    7.4
# 24    7.2
# 25    8.3
# 26    8.1
# 27    8.1
# 28    NaN
# 29    8.3
# 30    8.1
# 31    1.9
# 32    8.4
# 33    8.4
# 34    7.6
# 35    8.0
# 36    8.0
# Name: imdb_rating, dtype: float64

# %%
type(df.imdb_rating)
# Out:
# pandas.Series

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
dir(df.imdb_rating)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
print(df.imdb_rating.min(),df.imdb_rating.max(),df.imdb_rating.mean())
# Out:
# 1.9 9.3 7.919444444444445

# %%
db_b = df[df.industry=='Bollywood']
db_h = df[df.industry=='Hollywood']

# %%
db_b
# Out:
#                           title   industry  release_year  imdb_rating  \
# 0               Pather Panchali  Bollywood          1955          8.3
# 21  Dilwale Dulhania Le Jayenge  Bollywood          1995          8.0
# 22                     3 Idiots  Bollywood          2009          8.4
# 23     Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 24             Bajirao Mastani   Bollywood          2015          7.2
# 25             Taare Zameen Par  Bollywood          2007          8.3
# 26          Munna Bhai M.B.B.S.  Bollywood          2003          8.1
# 27                           PK  Bollywood          2014          8.1
# 28                        Sanju  Bollywood          2018          NaN
# 29            The Kashmir Files  Bollywood          2022          8.3
# 30            Bajrangi Bhaijaan  Bollywood          2015          8.1
# 31                       Race 3  Bollywood          2018          1.9
# ...

# %%
db_b
# Out:
#                           title   industry  release_year  imdb_rating  \
# 0               Pather Panchali  Bollywood          1955          8.3
# 21  Dilwale Dulhania Le Jayenge  Bollywood          1995          8.0
# 22                     3 Idiots  Bollywood          2009          8.4
# 23     Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 24             Bajirao Mastani   Bollywood          2015          7.2
# 25             Taare Zameen Par  Bollywood          2007          8.3
# 26          Munna Bhai M.B.B.S.  Bollywood          2003          8.1
# 27                           PK  Bollywood          2014          8.1
# 28                        Sanju  Bollywood          2018          NaN
# 29            The Kashmir Files  Bollywood          2022          8.3
# 30            Bajrangi Bhaijaan  Bollywood          2015          8.1
# 31                       Race 3  Bollywood          2018          1.9
# ...

# %%
print(db_b.imdb_rating.min(),db_b.imdb_rating.max(),db_b.imdb_rating.mean())
# Out:
# 1.9 8.4 7.656250000000001

# %%
print(db_h.imdb_rating.min(),db_h.imdb_rating.max(),db_h.imdb_rating.mean())
# Out:
# 6.8 9.3 8.130000000000003
