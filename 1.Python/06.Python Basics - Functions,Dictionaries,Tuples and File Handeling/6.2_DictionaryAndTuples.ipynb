# %%
expences=[1200,1400,1700]
expences[1]=100
expences
# Out:
# [1200, 100, 1700]

# %%
# Tuple is fixed sized and immutable
point=(5,6)
point[0]
# Out:
# 5

# %%
point[1]
# Out:
# 6

# %%
type(point)
# Out:
# tuple

# %%
point[1]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 point[1]=1
#
# TypeError: 'tuple' object does not support item assignment

# %%
point_3d=(5,8,10)

# %%
# Dictionaries
# Hashmaps is implemented using Dictionary in python
contacts =[('yogesh',7499665641),('omkar',29273991018)]

# %%
for contact in contacts:
    if contact[0]=="yogesh":
        print(contact[1])
        break
# Out:
# 7499665641

# %%
contacts ={'yogesh':7499665641,'omkar':29273991018}

# %%
type(contacts)
# Out:
# dict

# %%
contacts['yogesh']
# Out:
# 7499665641

# %%
contacts['yogi']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 contacts['yogi']
#
# KeyError: 'yogi'

# %%
contacts.get('yogi')

# %%
contacts['omkar']=18272227

# %%
contacts
# Out:
# {'yogesh': 7499665641, 'omkar': 18272227}

# %%
contacts['satya']=276372288

# %%
contacts
# Out:
# {'yogesh': 7499665641, 'omkar': 18272227, 'satya': 276372288}

# %%
del contacts['satya']

# %%
contacts
# Out:
# {'yogesh': 7499665641, 'omkar': 18272227}

# %%
'yogesh' in contacts
# Out:
# True

# %%
# Dictionary Inside Dictionary
contacts_dict={
    "Mahesh" : {"Phone":9876654321,"Branch":"ENTC"},
    "Amit" : {"Phone":9823443214,"Branch":"IT"}
}

# %%
contacts_dict["Mahesh"]["Phone"]
# Out:
# 9876654321

# %%
for name,number in contacts.items():
    print(f"Name : {name} \nNumber {number}\n")
# Out:
# Name : yogesh
# Number 7499665641
#
# Name : omkar
# Number 18272227

# %%
contacts.keys()
# Out:
# dict_keys(['yogesh', 'omkar'])

# %%
contacts.values()
# Out:
# dict_values([7499665641, 18272227])

# %%
for name, info in contacts_dict.items():
    print(f"Name : {name} ")
    for key , value in info.items():
        print(f"{key} : {value}")
    print()
# Out:
# Name : Mahesh
# Phone : 9876654321
# Branch : ENTC
#
# Name : Amit
# Phone : 9823443214
# Branch : IT

# %%
dir(contacts)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']
