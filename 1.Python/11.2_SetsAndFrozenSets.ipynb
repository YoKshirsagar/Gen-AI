# %%
myset = set([1,2,3,2,1,4])
myset
# Out:
# {1, 2, 3, 4}

# %%
myset = {1,2,3,2,1,4}
myset
# Out:
# {1, 2, 3, 4}

# %%
menu = set(["Dosa","Idli","Vada"])
menu
# Out:
# {'Dosa', 'Idli', 'Vada'}

# %%
menu.add("Pizza")
menu
# Out:
# {'Dosa', 'Idli', 'Pizza', 'Vada'}

# %%
menu.add("Pizza")
menu
# Out:
# {'Dosa', 'Idli', 'Pizza', 'Vada'}

# %%
menu.remove("Dosa")
menu
# Out:
# {'Idli', 'Pizza', 'Vada'}

# %%
menu = frozenset(["Dosa","Idli","Vada"])
menu
# Out:
# frozenset({'Dosa', 'Idli', 'Vada'})

# %%
menu.add("Pizza")
menu
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 menu.add("Pizza")
#       2 menu
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
menu = set(["Dosa","Idli","Vada"])
menu

# %%
"Dosa" in menu

# %%
"Burger" in menu
# Out:
# False

# %%
transactions = [
    {'customer_name': "Mira", "amount": 56, "date": "2024-08-01"},
    {'customer_name': "Mira", "amount": 12.3, "date": "2024-09-05"},
    {'customer_name': "Mohan", "amount": 21, "date": "2024-09-03"},
    {'customer_name': "Mohan", "amount": 36.8, "date": "2024-09-10"},
    {'customer_name': "Lucy", "amount": 66.3, "date": "2024-09-10"}
]

# %%
transactions
# Out:
# [{'customer_name': 'Mira', 'amount': 56, 'date': '2024-08-01'},
#  {'customer_name': 'Mira', 'amount': 12.3, 'date': '2024-09-05'},
#  {'customer_name': 'Mohan', 'amount': 21, 'date': '2024-09-03'},
#  {'customer_name': 'Mohan', 'amount': 36.8, 'date': '2024-09-10'},
#  {'customer_name': 'Lucy', 'amount': 66.3, 'date': '2024-09-10'}]

# %%
for trans in transactions:
    print(trans["customer_name"])
# Out:
# Mira
# Mira
# Mohan
# Mohan
# Lucy

# %%
customers = set()
for trans in transactions:
    customers.add(trans["customer_name"])
customers
# Out:
# {'Lucy', 'Mira', 'Mohan'}

# %%
customers_list = list(customers)
customers_list
# Out:
# ['Lucy', 'Mira', 'Mohan']

# %%
a = {"Mira","Mohan","Lucky","Ahmad"}
b = {"Chen","Mohan","Radha","Maria"}

# %%
a & b     #Intersection of Set
# Out:
# {'Mohan'}

# %%
a | b    # Union
# Out:
# {'Ahmad', 'Chen', 'Lucky', 'Maria', 'Mira', 'Mohan', 'Radha'}

# %%
a.union(b)
# Out:
# {'Ahmad', 'Chen', 'Lucky', 'Maria', 'Mira', 'Mohan', 'Radha'}

# %%
a - b # Difference
# Out:
# {'Ahmad', 'Lucky', 'Mira'}
