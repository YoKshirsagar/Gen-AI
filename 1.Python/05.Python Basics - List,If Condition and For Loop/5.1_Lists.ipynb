# %%
items=["bread","pasta","fruits","veggies"]
items
# Out:
# ['bread', 'pasta', 'fruits', 'veggies']

# %%
items[0]
# Out:
# 'bread'

# %%
items[:2]
# Out:
# ['bread', 'pasta']

# %%
items.append('butter')

# %%
items
# Out:
# ['bread', 'pasta', 'fruits', 'veggies', 'butter']

# %%
items.remove('butter')

# %%
items
# Out:
# ['bread', 'butter', 'pasta', 'fruits', 'veggies']

# %%
items.insert(1,'butter')
items
# Out:
# ['bread', 'butter', 'pasta', 'fruits', 'veggies']

# %%
items[1]='cheese'
items
# Out:
# ['bread', 'cheese', 'pasta', 'fruits', 'veggies']

# %%
items[3:]=['almonds']
items
# Out:
# ['bread', 'cheese', 'pasta', 'almonds']

# %%
'rice' in items
# Out:
# False

# %%
'bread' in items
# Out:
# True

# %%
expenses=[30,20,30,40,10]
expenses.sort(reverse=True)
expenses
# Out:
# [40, 30, 30, 20, 10]

# %%
items + expenses
# Out:
# ['bread', 'cheese', 'pasta', 'almonds', 40, 30, 30, 20, 10]

# %%
len(items)
# Out:
# 4

# %%
items.clear()

# %%
items
# Out:
# []
