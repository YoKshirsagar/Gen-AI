# %%
first="Yogesh"
second="kshirsagar"

# %%
type(first)
# Out:
# str

# %%
name = first + " " + second

# %%
name
# Out:
# 'Yogesh kshirsagar'

# %%
name = f"my name is {first} {second}"

# %%
name
# Out:
# 'my name is Yogesh kshirsagar'

# %%
first[0]
# Out:
# 'Y'

# %%
first[1]
# Out:
# 'o'

# %%
first[0:7]
# Out:
# 'Yogesh'

# %%
first[2:]
# Out:
# 'gesh'

# %%
first
# Out:
# 'Yogesh'

# %%
first[12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 first[12]
#
# IndexError: string index out of range

# %%
len(name)
# Out:
# 28

# %%
first[-1]
# Out:
# 'h'

# %%
name[0]='S'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 name[0]='S'
#
# TypeError: 'str' object does not support item assignment

# %%
str1='He said "hello"'
str2="he replied 'hii'"

# %%
str1,str2
# Out:
# ('He said "hello"', "he replied 'hii'")

# %%
str1
# Out:
# 'He said "hello"'

# %%
str3='''
Hello 
I am Yogesh Kshirsagar
How are you ?
'''

# %%
str3
# Out:
# '\nHello \nI am Yogesh Kshirsagar\nHow are you ?\n'

# %%
print(str3)
# Out:
# Hello
# I am Yogesh Kshirsagar
# How are you ?

# %%
str4="Hello"
str4 in str3
# Out:
# True

# %%
"milk" in str3
# Out:
# False

# %%
str3.find(str4)
# Out:
# 1

# %%
str3.find("milk")
# Out:
# -1

# %%
dir(str3)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
s="Patient was charged 100$ for lab test"
s
# Out:
# 'Patient was charged 100$ for lab test'

# %%
s= s.replace("100$","10$")

# %%
s
# Out:
# 'Patient was charged 10$ for lab test'

# %%
s.upper()
# Out:
# 'PATIENT WAS CHARGED 10$ FOR LAB TEST'

# %%
s.lower()
# Out:
# 'patient was charged 10$ for lab test'

# %%
'201'.isdigit()
# Out:
# True

# %%
'2a34'.isdigit()
# Out:
# False

# %%
s.index("10$")
# Out:
# 20

# %%
text = "my age is"
age = 21
text + age
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 text = "my age is"
#       2 age = 21
# ----> 3 text + age
#
# TypeError: can only concatenate str (not "int") to str

# %%
text = "my age is"
age = 21
text + str(age)
# Out:
# 'my age is21'

# %%
s="hey\tbro"
print(s)
# Out:
# hey	bro

# %%
tickers = "AAPL|NVDA|RIL|GOGL"
tickers.split("|")
# Out:
# ['AAPL', 'NVDA', 'RIL', 'GOGL']

# %%
tickers = "AAPL|NVDA|RIL|GOGL"
tickers.split("|",maxsplit=2)
# Out:
# ['AAPL', 'NVDA', 'RIL|GOGL']

# %%
s="           Patient was charged 100$ for lab test                 "
s.strip()
# Out:
# 'Patient was charged 100$ for lab test'

# %%
file_name='report.pdf'
file_name.endswith(".pdf")
# Out:
# True
