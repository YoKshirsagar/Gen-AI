# %%
print("Hello")
# Out:
# Hello

# %%
can="soda"

# %%
can
# Out:
# 'soda'

# %%
type(can)
# Out:
# str

# %%
pizza=100
pizza
# Out:
# 100

# %%
type(pizza)
# Out:
# int

# %%
samosa=20.5
icecream=100

# %%
total = pizza +samosa+icecream

# %%
total
# Out:
# 220.5

# %%
type(total)
# Out:
# float

# %%
total>200
# Out:
# True

# %%
total<200
# Out:
# False

# %%
can=2.3
can
# Out:
# 2.3

# %%
foo="jalebi"

# %%
foo
# Out:
# 'jalebi'

# %%
bar=foo
bar
# Out:
# 'jalebi'

# %%
id(foo)
# Out:
# 3144569632688

# %%
id(bar)
# Out:
# 3144569632688

# %%
bar=samosa

# %%
id(bar)
# Out:
# 3144562914992
