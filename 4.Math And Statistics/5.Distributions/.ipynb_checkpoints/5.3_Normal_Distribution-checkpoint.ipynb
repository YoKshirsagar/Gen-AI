# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("5.3_Normal_Distribution_heights.csv")
df.head(3)
# Out:
#        name  height
# 0     Aarav    5.45
# 1   Deepika    5.61
# 2  Abhishek    5.65

# %%
df.shape
# Out:
# (1000, 2)

# %%
sns.histplot(df.height)
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
sns.histplot(df.height,kde=True)
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
mean = df.height.mean()
std = df.height.std()

mean,std
# Out:
# (np.float64(5.609439999999999), np.float64(0.32750411500520926))

# %%
mean = round(df.height.mean(),2)
std = round(df.height.std(),2)

mean,std
# Out:
# (np.float64(5.61), np.float64(0.33))

# %%
sns.histplot(df.height,kde=True)
plt.axvline(mean, color='k', linestyle='dashed', linewidth=1)

# %%
sns.histplot(df.height,kde=True)
plt.axvline(mean, color='k', linestyle='dashed', linewidth=1)

# one stadard deviation
plt.axvline(mean + std, color='r', linestyle='dashed', linewidth=1)
plt.axvline(mean - std, color='r', linestyle='dashed', linewidth=1)

# %%
sns.histplot(df.height, kde=True)

plt.axvline(mean, color='k', linestyle='dashed', linewidth=1)

# one stadard deviation
plt.axvline(mean + std, color='r', linestyle='dashed', linewidth=1)
plt.axvline(mean - std, color='r', linestyle='dashed', linewidth=1)

# two standard deviation
plt.axvline(mean + 2*std, color='g', linestyle='dashed', linewidth=1)
plt.axvline(mean - 2*std, color='g', linestyle='dashed', linewidth=1)

# %%
sns.histplot(df.height, kde=True)

plt.axvline(mean, color='k', linestyle='dashed', linewidth=1)

# one stadard deviation
plt.axvline(mean + std, color='r', linestyle='dashed', linewidth=1)
plt.axvline(mean - std, color='r', linestyle='dashed', linewidth=1)

# two standard deviation
plt.axvline(mean + 2*std, color='g', linestyle='dashed', linewidth=1)
plt.axvline(mean - 2*std, color='g', linestyle='dashed', linewidth=1)

# three standard deviation
plt.axvline(mean + 3*std, color='b', linestyle='dashed', linewidth=1)
plt.axvline(mean - 3*std, color='b', linestyle='dashed', linewidth=1)

# %%
left1 = mean - std
right1 = mean + std
left1 , right1
# Out:
# (np.float64(5.28), np.float64(5.94))

# %%
left2 = mean - 2*std
right2 = round(mean + 2*std,2)
left2 , right2
# Out:
# (np.float64(4.95), np.float64(6.27))

# %%
left3 = mean - 3*std
right3 = round(mean + 3*std,2)
left3 , right3
# Out:
# (np.float64(4.62), np.float64(6.6))

# %%
df[(df.height>left1)&(df.height<right1)]
# Out:
#          name  height
# 0       Aarav    5.45
# 1     Deepika    5.61
# 2    Abhishek    5.65
# 3       Sneha    5.52
# 4       Kriti    5.69
# ..        ...     ...
# 994   Jessica    5.46
# 995     Susan    5.51
# 996     Sarah    5.85
# 998   Michael    5.81
# 999     David    5.41
#
# [641 rows x 2 columns]

# %%
df[(df.height>left1)&(df.height<right1)].shape
# Out:
# (641, 2)

# %%
df[(df.height>left2)&(df.height<right2)].shape
# Out:
# (970, 2)

# %%
df[(df.height>left3)&(df.height<right3)].shape
# Out:
# (999, 2)
